# %% [markdown]
# <a href="https://colab.research.google.com/github/DinhQuocTuan0108/Bai-tap/blob/main/MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# !pip3 install mtcnn
# !pip3 install opencv-contrib-python
from mtcnn import MTCNN
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
url="/content/2.jpg"

# %%
pics=plt.imread(url)

# %%
detetor=MTCNN()

# %%
face=detetor.detect_faces(pics)
# Out:
# ...
# 1/1 [==============================] - 0s 161ms/step

# %%
for face in face :
  print(face)
# Out:
# {'box': [238, 159, 11, 16], 'confidence': 0.9620868563652039, 'keypoints': {'left_eye': (239, 166), 'right_eye': (244, 165), 'nose': (241, 169), 'mouth_left': (240, 172), 'mouth_right': (244, 172)}}
# {'box': [129, 137, 10, 14], 'confidence': 0.7895796298980713, 'keypoints': {'left_eye': (132, 142), 'right_eye': (137, 142), 'nose': (134, 145), 'mouth_left': (132, 148), 'mouth_right': (136, 149)}}

# %%
from numpy.core.multiarray import dot
import matplotlib.pyplot as plt
from mtcnn import MTCNN
url="/content/2.jpg"
pixels=plt.imread(url)
detector=MTCNN()
faces = detector.detect_faces(pixels)
plt.imshow(pixels)
ax=plt.gca()
for face in faces :
  x,y,width,height=face['box']
  rect = plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 174ms/step

# %%
from numpy.core.multiarray import dot
import matplotlib.pyplot as plt
from mtcnn import MTCNN
url="2.jpg"
pixels=plt.imread(url)
detector=MTCNN()
faces = detector.detect_faces(pixels)
plt.imshow(pixels)
ax=plt.gca()
for face in faces :
  x,y,width,height=face['box']
  rect = plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  for key,value in face['keypoints'].items() :
    dot = plt.Circle(value,radius=2,color="red")
    ax.add_patch(dot)
# Out:
# ...
# 1/1 [==============================] - 0s 146ms/step

# %%
def draw_faces (filename,result_list):
  data=plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height=result_list[i]['box']
    x2,y2=x1+width,y1+height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
plt.show()  
filename="/content/tải xuống.jpg"
pixels=plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(pixels)
draw_faces(filename,faces)
# Out:
# ...
# 1/1 [==============================] - 0s 152ms/step
